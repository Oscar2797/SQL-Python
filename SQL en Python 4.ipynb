# %%
import sqlite3
conn= sqlite3.connect("ClientesVarios.db")

# %%
cur=conn.cursor()

# %%
# Lectura de archvo csv

import os
import csv

os.chdir("C:/Users/odela/Downloads")
with open("Customers1.csv") as f:
    reader= csv.reader(f)
    data=list(reader)
data
# Out:
# [['CustomerName', 'Address', 'City', 'Country'],
#  ['Alfreds Futterkiste', 'Obere Str. 57', 'Berlin', 'Germany'],
#  ['Ana Trujillo Emparedados y helados',
#   'Avda. de la Constituci?n 2222',
#   'M?xico D.F.',
#   'Mexico'],
#  ['Antonio Moreno Taquer?a', 'Mataderos 2312', 'M?xico D.F.', 'Mexico'],
#  ['Around the Horn', '120 Hanover Sq.', 'London', 'UK'],
#  ['Berglunds snabbk?p', 'Berguvsv?gen 8', 'Lule?', 'Sweden'],
#  ['Blauer See Delikatessen', 'Forsterstr. 57', 'Mannheim', 'Germany'],
#  ['Blondel p?re et fils', '24, place Kl?ber', 'Strasbourg', 'France'],
#  ['B?lido Comidas preparadas', 'C/ Araquil, 67', 'Madrid', 'Spain'],
#  ["Bon app'", '12, rue des Bouchers', 'Marseille', 'France'],
#  ['Bottom-Dollar Marketse', '23 Tsawassen Blvd.', 'Tsawassen', 'Canada'],
#  ["B's Beverages", 'Fauntleroy Circus', 'London', 'UK'],
#  ['Cactus Comidas para llevar', 'Cerrito 333', 'Buenos Aires', 'Argentina'],
#  ['Centro comercial Moctezuma',
#   'Sierras de Granada 9993',
# ...

# %%
len(data)
# Out:
# 92

# %%
# Creación de la tabla donde se importara la tabla CSV
cur.execute("""CREATE TABLE Customers1(
              CustomerName TEXT PRIMARY KEY,
              Address TEXT,
              City TEXT,
              Country TEXT);""")

# %%
# Inserción de datos en tabla

for renglon in range(1, len(data)):
    cur.execute("""
                INSERT INTO Customers1(CustomerName, Address, City, Country)
                VALUES(?,?,?,?)
                """, data[renglon])

# %%
conn.commit()

# %%
# Lectura de archivo 2 csv

os.chdir("C:/Users/odela/Downloads")
with open("Customers2.csv") as f:
    reader= csv.reader(f)
    data=list(reader)
data
# Out:
# [['CustomerName', 'ContactName', 'PostalCode', 'PurchaseUSD'],
#  ['Asociacion de comerciantes', 'Julio Glockner', '1546', '5680'],
#  ['Alfreds Futterkiste', 'Maria Anders', '12209', '14861'],
#  ['Ana Trujillo Emparedados y helados', 'Ana Trujillo', '5021', '9900'],
#  ['Antonio Moreno Taquer?a', 'Antonio Moreno', '5023', '7735'],
#  ['Around the Horn', 'Thomas Hardy', 'WA1 1DP', '10295'],
#  ['Berglunds snabbk?p', 'Christina Berglund', 'S-958 22', '6755'],
#  ['Burundi Producciones', 'Ramiro Flores', '1678', '3456'],
#  ['Blauer See Delikatessen', 'Hanna Moos', '68306', '12721'],
#  ['Blondel p?re et fils', 'Fr?d?rique Citeaux', '67000', '11426'],
#  ['B?lido Comidas preparadas', 'Mart?n Sommer', '28023', '17246'],
#  ["Bon app'", 'Laurence Lebihans', '13008', '11816'],
#  ['Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'T2F 8M4', '6526'],
#  ["B's Beverages", 'Victoria Ashworth', 'EC2 5NT', '10891'],
#  ['Chop-suey Chinese', 'Yang Wang', '3012', '17712'],
# ...

# %%
len(data)
# Out:
# 77

# %%
cur.execute("""CREATE TABLE Customers2(
              CustomerName TEXT PRIMARY KEY,
              ContactName TEXT,
              PostalCode TEXT,
              PurchaseUSD INTEGER);""")

# %%
for renglon in range(1, len(data)):
    cur.execute("""
                INSERT INTO Customers2(CustomerName, ContactName, PostalCode, PurchaseUSD)
                VALUES(?,?,?,?)
                """, data[renglon])

# %%
conn.commit()

# %%
# Revisión tabla 1

cur.execute("SELECT * FROM Customers1 LIMIT 10;")
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Obere Str. 57', 'Berlin', 'Germany'),
#  ('Ana Trujillo Emparedados y helados',
#   'Avda. de la Constituci?n 2222',
#   'M?xico D.F.',
#   'Mexico'),
#  ('Antonio Moreno Taquer?a', 'Mataderos 2312', 'M?xico D.F.', 'Mexico'),
#  ('Around the Horn', '120 Hanover Sq.', 'London', 'UK'),
#  ('Berglunds snabbk?p', 'Berguvsv?gen 8', 'Lule?', 'Sweden'),
#  ('Blauer See Delikatessen', 'Forsterstr. 57', 'Mannheim', 'Germany'),
#  ('Blondel p?re et fils', '24, place Kl?ber', 'Strasbourg', 'France'),
#  ('B?lido Comidas preparadas', 'C/ Araquil, 67', 'Madrid', 'Spain'),
#  ("Bon app'", '12, rue des Bouchers', 'Marseille', 'France'),
#  ('Bottom-Dollar Marketse', '23 Tsawassen Blvd.', 'Tsawassen', 'Canada')]

# %%
# Revisión tabla 2

cur.execute("SELECT * FROM Customers2 LIMIT 10;")
result= cur.fetchall()
result
# Out:
# [('Asociacion de comerciantes', 'Julio Glockner', '1546', 5680),
#  ('Alfreds Futterkiste', 'Maria Anders', '12209', 14861),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', '5021', 9900),
#  ('Antonio Moreno Taquer?a', 'Antonio Moreno', '5023', 7735),
#  ('Around the Horn', 'Thomas Hardy', 'WA1 1DP', 10295),
#  ('Berglunds snabbk?p', 'Christina Berglund', 'S-958 22', 6755),
#  ('Burundi Producciones', 'Ramiro Flores', '1678', 3456),
#  ('Blauer See Delikatessen', 'Hanna Moos', '68306', 12721),
#  ('Blondel p?re et fils', 'Fr?d?rique Citeaux', '67000', 11426),
#  ('B?lido Comidas preparadas', 'Mart?n Sommer', '28023', 17246)]

# %%
# Consutla mediante INNER JOIN

cur.execute( """ SELECT p1.CustomerName, p1.City, p2.ContactName, p2.PurchaseUSD 
                 FROM Customers1 AS p1 INNER JOIN Customers2 AS p2
                 ON p1.CustomerName= p2.CustomerName;""")
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Berlin', 'Maria Anders', 14861),
#  ('Ana Trujillo Emparedados y helados', 'M?xico D.F.', 'Ana Trujillo', 9900),
#  ('Antonio Moreno Taquer?a', 'M?xico D.F.', 'Antonio Moreno', 7735),
#  ('Around the Horn', 'London', 'Thomas Hardy', 10295),
#  ('Berglunds snabbk?p', 'Lule?', 'Christina Berglund', 6755),
#  ('Blauer See Delikatessen', 'Mannheim', 'Hanna Moos', 12721),
#  ('Blondel p?re et fils', 'Strasbourg', 'Fr?d?rique Citeaux', 11426),
#  ('B?lido Comidas preparadas', 'Madrid', 'Mart?n Sommer', 17246),
#  ("Bon app'", 'Marseille', 'Laurence Lebihans', 11816),
#  ('Bottom-Dollar Marketse', 'Tsawassen', 'Elizabeth Lincoln', 6526),
#  ("B's Beverages", 'London', 'Victoria Ashworth', 10891),
#  ('Chop-suey Chinese', 'Bern', 'Yang Wang', 17712),
#  ('Com?rcio Mineiro', 'S?o Paulo', 'Pedro Afonso', 9193),
#  ('Consolidated Holdings', 'London', 'Elizabeth Brown', 19895),
#  ('Drachenblut Delikatessend', 'Aachen', 'Sven Ottlieb', 8530),
# ...

# %%
# OTRA ALTERNATIVA (NO REQUIERE DEFINIR TABLA 2)

cur.execute( """ SELECT p1.CustomerName, p1.City, ContactName, PurchaseUSD 
                 FROM Customers1 AS p1 INNER JOIN Customers2 AS p2
                 ON p1.CustomerName= p2.CustomerName;""")
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Berlin', 'Maria Anders', 14861),
#  ('Ana Trujillo Emparedados y helados', 'M?xico D.F.', 'Ana Trujillo', 9900),
#  ('Antonio Moreno Taquer?a', 'M?xico D.F.', 'Antonio Moreno', 7735),
#  ('Around the Horn', 'London', 'Thomas Hardy', 10295),
#  ('Berglunds snabbk?p', 'Lule?', 'Christina Berglund', 6755),
#  ('Blauer See Delikatessen', 'Mannheim', 'Hanna Moos', 12721),
#  ('Blondel p?re et fils', 'Strasbourg', 'Fr?d?rique Citeaux', 11426),
#  ('B?lido Comidas preparadas', 'Madrid', 'Mart?n Sommer', 17246),
#  ("Bon app'", 'Marseille', 'Laurence Lebihans', 11816),
#  ('Bottom-Dollar Marketse', 'Tsawassen', 'Elizabeth Lincoln', 6526),
#  ("B's Beverages", 'London', 'Victoria Ashworth', 10891),
#  ('Chop-suey Chinese', 'Bern', 'Yang Wang', 17712),
#  ('Com?rcio Mineiro', 'S?o Paulo', 'Pedro Afonso', 9193),
#  ('Consolidated Holdings', 'London', 'Elizabeth Brown', 19895),
#  ('Drachenblut Delikatessend', 'Aachen', 'Sven Ottlieb', 8530),
# ...

# %%
# OTRA ALTERNATIVA MEDIANTE COMANDO USING (SÓLO APLICA CUANDO AMBAS TABLAS TIENEN EL MISMO NOMBRE EN EL CAMPO EN COMÚN, en este caso CustomerName)

cur.execute("""SELECT p1.CustomerName, p1.City, CustomerName, PurchaseUSD
               FROM Customers1 AS p1 INNER JOIN Customers2 AS p2
               USING (CustomerName);""")
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Berlin', 'Alfreds Futterkiste', 14861),
#  ('Ana Trujillo Emparedados y helados',
#   'M?xico D.F.',
#   'Ana Trujillo Emparedados y helados',
#   9900),
#  ('Antonio Moreno Taquer?a', 'M?xico D.F.', 'Antonio Moreno Taquer?a', 7735),
#  ('Around the Horn', 'London', 'Around the Horn', 10295),
#  ('Berglunds snabbk?p', 'Lule?', 'Berglunds snabbk?p', 6755),
#  ('Blauer See Delikatessen', 'Mannheim', 'Blauer See Delikatessen', 12721),
#  ('Blondel p?re et fils', 'Strasbourg', 'Blondel p?re et fils', 11426),
#  ('B?lido Comidas preparadas', 'Madrid', 'B?lido Comidas preparadas', 17246),
#  ("Bon app'", 'Marseille', "Bon app'", 11816),
#  ('Bottom-Dollar Marketse', 'Tsawassen', 'Bottom-Dollar Marketse', 6526),
#  ("B's Beverages", 'London', "B's Beverages", 10891),
#  ('Chop-suey Chinese', 'Bern', 'Chop-suey Chinese', 17712),
#  ('Com?rcio Mineiro', 'S?o Paulo', 'Com?rcio Mineiro', 9193),
#  ('Consolidated Holdings', 'London', 'Consolidated Holdings', 19895),
# ...

# %%
#  CONSULTA MEDIANTE LEFT JOIN

cur.execute( """ SELECT p1.CustomerName, p1.City, p2.ContactName, p2.PurchaseUSD 
                 FROM Customers1 AS p1 LEFT JOIN Customers2 AS p2
                 ON p1.CustomerName= p2.CustomerName;""")
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Berlin', 'Maria Anders', 14861),
#  ('Ana Trujillo Emparedados y helados', 'M?xico D.F.', 'Ana Trujillo', 9900),
#  ('Antonio Moreno Taquer?a', 'M?xico D.F.', 'Antonio Moreno', 7735),
#  ('Around the Horn', 'London', 'Thomas Hardy', 10295),
#  ('Berglunds snabbk?p', 'Lule?', 'Christina Berglund', 6755),
#  ('Blauer See Delikatessen', 'Mannheim', 'Hanna Moos', 12721),
#  ('Blondel p?re et fils', 'Strasbourg', 'Fr?d?rique Citeaux', 11426),
#  ('B?lido Comidas preparadas', 'Madrid', 'Mart?n Sommer', 17246),
#  ("Bon app'", 'Marseille', 'Laurence Lebihans', 11816),
#  ('Bottom-Dollar Marketse', 'Tsawassen', 'Elizabeth Lincoln', 6526),
#  ("B's Beverages", 'London', 'Victoria Ashworth', 10891),
#  ('Cactus Comidas para llevar', 'Buenos Aires', None, None),
#  ('Centro comercial Moctezuma', 'M?xico D.F.', None, None),
#  ('Chop-suey Chinese', 'Bern', 'Yang Wang', 17712),
#  ('Com?rcio Mineiro', 'S?o Paulo', 'Pedro Afonso', 9193),
# ...

# %%
#  USO DE CASE WHEN para separar por clases los grupos de compra (END AS define el nombre de la columna que se crea)

cur.execute("""SELECT CustomerName, ContactName,
               CASE WHEN PurchaseUSD< 10000 THEN "Venta baja"
               WHEN PurchaseUSD<= 15000 THEN "Venta media"
               ELSE "Venta alta" END AS Grupo_Venta
               FROM Customers2
               ORDER BY Grupo_Venta;""")
result= cur.fetchall()
result
# Out:
# [('B?lido Comidas preparadas', 'Mart?n Sommer', 'Venta alta'),
#  ('Chop-suey Chinese', 'Yang Wang', 'Venta alta'),
#  ('Consolidated Holdings', 'Elizabeth Brown', 'Venta alta'),
#  ('Eastern Connection', 'Ann Devon', 'Venta alta'),
#  ('Folies gourmandes', 'Martine Ranc?', 'Venta alta'),
#  ('Island Trading', 'Helen Bennett', 'Venta alta'),
#  ('Lazy K Kountry Store', 'John Steel', 'Venta alta'),
#  ('Lehmanns Marktstand', 'Renate Messner', 'Venta alta'),
#  ("Let's Stop N Shop", 'Jaime Yorres', 'Venta alta'),
#  ('Lonesome Pine Restaurant', 'Fran Wilson', 'Venta alta'),
#  ('M?re Paillarde', 'Jean Fresni?re', 'Venta alta'),
#  ('Morgenstern Gesundkost', 'Alexander Feuer', 'Venta alta'),
#  ('North/South', 'Simon Crowther', 'Venta alta'),
#  ('Paris sp?cialit?s', 'Marie Bertrand', 'Venta alta'),
#  ('Sant? Gourmet', 'Jonas Bergulfsen', 'Venta alta'),
#  ('Save-a-lot Markets', 'Jose Pavarotti', 'Venta alta'),
#  ('Supr?mes d?lices', 'Pascale Cartrain', 'Venta alta'),
# ...

# %%
# TABLA 3

os.chdir("C:/Users/odela/Downloads")
with open("Customers3.csv") as f:
    reader= csv.reader(f)
    data=list(reader)
data
# Out:
# [['CustomerName', 'ContactName', 'PostalCode', 'PurchaseUSD'],
#  ['Sant? Gourmet', 'Jonas Bergulfsen', '4110', '19591'],
#  ['Save-a-lot Markets', 'Jose Pavarotti', '83720', '15890'],
#  ['Seven Seas Imports', 'Hari Kumar', 'OX15 4NB', '12052'],
#  ['Simons bistro', 'Jytte Petersen', '1734', '14175'],
#  ['Sp?cialit?s du monde', 'Dominique Perrier', '75016', '13613'],
#  ['Split Rail Beer & Ale', 'Art Braunschweiger', '82520', '9930'],
#  ['Supr?mes d?lices', 'Pascale Cartrain', 'B-6000', '16128'],
#  ['Toms Spezialit?ten', 'Karin Josephs', '44087', '18851'],
#  ['Tortuga Restaurante', 'Miguel Angel Paolino', '5033', '8327'],
#  ['Tradi??o Hipermercados', 'Anabela Domingues', '05634-030', '12676'],
#  ["Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '98034', '8749'],
#  ['Vaffeljernet', 'Palle Ibsen', '8200', '10379'],
#  ['Victuailles en stock', 'Mary Saveley', '69004', '10653'],
#  ['Vins et alcools Chevalier', 'Paul Henriot', '51100', '12696'],
# ...

# %%
cur.execute("""CREATE TABLE Customers3(
              CustomerName TEXT PRIMARY KEY,
              ContactName TEXT,
              PostalCode TEXT,
              PurchaseUSD INTEGER);""")

# %%
for renglon in range(1, len(data)):
    cur.execute("""
                INSERT INTO Customers3(CustomerName, ContactName, PostalCode, PurchaseUSD)
                VALUES(?,?,?,?)
                """, data[renglon])

# %%
conn.commit()

# %%
# Uso de operaión UNION (No repite registros)

cur.execute(""" SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers2
                UNION 
                SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers3
                ORDER BY CustomerName;
            """)
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Maria Anders', '12209', 14861),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', '5021', 9900),
#  ('Antonio Moreno Taquer?a', 'Antonio Moreno', '5023', 7735),
#  ('Around the Horn', 'Thomas Hardy', 'WA1 1DP', 10295),
#  ('Asociacion de comerciantes', 'Julio Glockner', '1546', 5680),
#  ("B's Beverages", 'Victoria Ashworth', 'EC2 5NT', 10891),
#  ('B?lido Comidas preparadas', 'Mart?n Sommer', '28023', 17246),
#  ('Berglunds snabbk?p', 'Christina Berglund', 'S-958 22', 6755),
#  ('Blauer See Delikatessen', 'Hanna Moos', '68306', 12721),
#  ('Blondel p?re et fils', 'Fr?d?rique Citeaux', '67000', 11426),
#  ("Bon app'", 'Laurence Lebihans', '13008', 11816),
#  ('Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'T2F 8M4', 6526),
#  ('Burundi Producciones', 'Ramiro Flores', '1678', 3456),
#  ('Chop-suey Chinese', 'Yang Wang', '3012', 17712),
#  ('Com?rcio Mineiro', 'Pedro Afonso', '05432-043', 9193),
# ...

# %%
# Uso de operaión UNION ALL (Sí repite registros)

cur.execute(""" SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers2
                UNION ALL
                SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers3
                ORDER BY CustomerName;
            """)
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Maria Anders', '12209', 14861),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', '5021', 9900),
#  ('Antonio Moreno Taquer?a', 'Antonio Moreno', '5023', 7735),
#  ('Around the Horn', 'Thomas Hardy', 'WA1 1DP', 10295),
#  ('Asociacion de comerciantes', 'Julio Glockner', '1546', 5680),
#  ("B's Beverages", 'Victoria Ashworth', 'EC2 5NT', 10891),
#  ('B?lido Comidas preparadas', 'Mart?n Sommer', '28023', 17246),
#  ('Berglunds snabbk?p', 'Christina Berglund', 'S-958 22', 6755),
#  ('Blauer See Delikatessen', 'Hanna Moos', '68306', 12721),
#  ('Blondel p?re et fils', 'Fr?d?rique Citeaux', '67000', 11426),
#  ("Bon app'", 'Laurence Lebihans', '13008', 11816),
#  ('Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'T2F 8M4', 6526),
#  ('Burundi Producciones', 'Ramiro Flores', '1678', 3456),
#  ('Chop-suey Chinese', 'Yang Wang', '3012', 17712),
#  ('Com?rcio Mineiro', 'Pedro Afonso', '05432-043', 9193),
# ...

# %%
# uso de la operación INTERSECT (Sólo muestra registros comunes)

cur.execute(""" SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers2
                INTERSECT
                SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers3
                ORDER BY CustomerName;
            """)
result= cur.fetchall()
result
# Out:
# [('Sant? Gourmet', 'Jonas Bergulfsen', '4110', 19591),
#  ('Save-a-lot Markets', 'Jose Pavarotti', '83720', 15890),
#  ('Seven Seas Imports', 'Hari Kumar', 'OX15 4NB', 12052),
#  ('Simons bistro', 'Jytte Petersen', '1734', 14175),
#  ('Sp?cialit?s du monde', 'Dominique Perrier', '75016', 13613),
#  ('Split Rail Beer & Ale', 'Art Braunschweiger', '82520', 9930),
#  ('Supr?mes d?lices', 'Pascale Cartrain', 'B-6000', 16128)]

# %%
# uso de la operación EXCEPT (Muestra los registros de la primer tabla y que no están en la segunda)

cur.execute(""" SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers2
                EXCEPT
                SELECT CustomerName, ContactName, PostalCode, PurchaseUSD
                FROM Customers3
                ORDER BY CustomerName;
            """)
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Maria Anders', '12209', 14861),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', '5021', 9900),
#  ('Antonio Moreno Taquer?a', 'Antonio Moreno', '5023', 7735),
#  ('Around the Horn', 'Thomas Hardy', 'WA1 1DP', 10295),
#  ('Asociacion de comerciantes', 'Julio Glockner', '1546', 5680),
#  ("B's Beverages", 'Victoria Ashworth', 'EC2 5NT', 10891),
#  ('B?lido Comidas preparadas', 'Mart?n Sommer', '28023', 17246),
#  ('Berglunds snabbk?p', 'Christina Berglund', 'S-958 22', 6755),
#  ('Blauer See Delikatessen', 'Hanna Moos', '68306', 12721),
#  ('Blondel p?re et fils', 'Fr?d?rique Citeaux', '67000', 11426),
#  ("Bon app'", 'Laurence Lebihans', '13008', 11816),
#  ('Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'T2F 8M4', 6526),
#  ('Burundi Producciones', 'Ramiro Flores', '1678', 3456),
#  ('Chop-suey Chinese', 'Yang Wang', '3012', 17712),
#  ('Com?rcio Mineiro', 'Pedro Afonso', '05432-043', 9193),
# ...

# %%
# SEMI JOIN Ejemplo ( datos que están dentro de condición de un asegunda tabla)

cur.execute(""" SELECT CustomerName, Country
                FROM Customers1
                WHERE CustomerName IN
                    (SELECT CustomerName
                     FROM Customers2
                     WHERE PurchaseUSD<10000);
            """)
result= cur.fetchall()
result
# Out:
# [('Ana Trujillo Emparedados y helados', 'Mexico'),
#  ('Antonio Moreno Taquer?a', 'Mexico'),
#  ('Berglunds snabbk?p', 'Sweden'),
#  ('Bottom-Dollar Marketse', 'Canada'),
#  ('Com?rcio Mineiro', 'Brazil'),
#  ('Drachenblut Delikatessend', 'Germany'),
#  ('Du monde entier', 'France'),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Spain'),
#  ('Familia Arquibaldo', 'Brazil'),
#  ('Folk och f? HB', 'Sweden'),
#  ('France restauration', 'France'),
#  ('Franchi S.p.A.', 'Italy'),
#  ('Frankenversand', 'Germany'),
#  ('Furia Bacalhau e Frutos do Mar', 'Portugal'),
#  ('GROSELLA-Restaurante', 'Venezuela'),
#  ('Hanari Carnes', 'Brazil'),
#  ('Hungry Coyote Import Store', 'USA'),
#  ('K?niglich Essen', 'Germany'),
#  ('LILA-Supermercado', 'Venezuela'),
#  ("La maison d'Asie", 'France'),
#  ('Magazzini Alimentari Riuniti', 'Italy'),
#  ('Old World Delicatessen', 'USA'),
#  ('Piccolo und mehr', 'Austria'),
#  ('Princesa Isabel Vinhoss', 'Portugal'),
#  ('Que Del?cia', 'Brazil'),
# ...

# %%
# ANTI JOIN Ejemplo (datos que no están en condición de una segunda tabla)

cur.execute(""" SELECT CustomerName, Country
                FROM Customers1
                WHERE CustomerName NOT IN
                    (SELECT CustomerName
                     FROM Customers2
                     WHERE PurchaseUSD<10000);
            """)
result= cur.fetchall()
result
# Out:
# [('Alfreds Futterkiste', 'Germany'),
#  ('Around the Horn', 'UK'),
#  ('Blauer See Delikatessen', 'Germany'),
#  ('Blondel p?re et fils', 'France'),
#  ('B?lido Comidas preparadas', 'Spain'),
#  ("Bon app'", 'France'),
#  ("B's Beverages", 'UK'),
#  ('Cactus Comidas para llevar', 'Argentina'),
#  ('Centro comercial Moctezuma', 'Mexico'),
#  ('Chop-suey Chinese', 'Switzerland'),
#  ('Consolidated Holdings', 'UK'),
#  ('Eastern Connection', 'UK'),
#  ('Ernst Handel', 'Austria'),
#  ('Folies gourmandes', 'France'),
#  ('Galer?a del gastr?nomo', 'Spain'),
#  ('Godos Cocina T?pica', 'Spain'),
#  ('Gourmet Lanchonetes', 'Brazil'),
#  ('Great Lakes Food Market', 'USA'),
#  ('HILARI?N-Abastos', 'Venezuela'),
#  ('Hungry Owl All-Night Grocers', 'Ireland'),
#  ('Island Trading', 'UK'),
#  ("La corne d'abondance", 'France'),
#  ('Laughing Bacchus Wine Cellars', 'Canada'),
#  ('Lazy K Kountry Store', 'USA'),
#  ('Lehmanns Marktstand', 'Germany'),
#  ("Let's Stop N Shop", 'USA'),
# ...

# %%
# Uso de subquery para seleccionar clientes cuyo monto de compra sea menor al promedio general

cur.execute(""" SELECT CustomerName, PurchaseUSD
                FROM Customers2
                WHERE PurchaseUSD <
                    (SELECT AVG(PurchaseUSD) FROM Customers2);
            """)
result= cur.fetchall()
result
# Out:
# [('Asociacion de comerciantes', 5680),
#  ('Ana Trujillo Emparedados y helados', 9900),
#  ('Antonio Moreno Taquer?a', 7735),
#  ('Around the Horn', 10295),
#  ('Berglunds snabbk?p', 6755),
#  ('Burundi Producciones', 3456),
#  ('Blondel p?re et fils', 11426),
#  ('Bottom-Dollar Marketse', 6526),
#  ("B's Beverages", 10891),
#  ('Com?rcio Mineiro', 9193),
#  ('Drachenblut Delikatessend', 8530),
#  ('Du monde entier', 6805),
#  ('Familia Arquibaldo', 7450),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 9835),
#  ('Folk och f? HB', 5875),
#  ('Frankenversand', 6426),
#  ('France restauration', 9193),
#  ('Franchi S.p.A.', 9410),
#  ('Furia Bacalhau e Frutos do Mar', 6447),
#  ('GROSELLA-Restaurante', 9053),
#  ('Hanari Carnes', 7732),
#  ('Hungry Coyote Import Store', 6272),
#  ('K?niglich Essen', 5459),
#  ("La maison d'Asie", 9259),
#  ('Laughing Bacchus Wine Cellars', 11072),
#  ('LILA-Supermercado', 9386),
#  ('Magazzini Alimentari Riuniti', 5171),
# ...
